# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/ASP.NET-Coding/blob/master/28-February-2026-Six-LNN-models-80-epoch-20-patience-graphs-without-data-augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/LNN
# Out:
# /content/LNN

# %%
# %pwd
# Out:
# '/content/LNN'

# %%
# !python test_all_models_80epochs.py
# Out:
# Loading REDD data...
#
# ...
# LNN COMPREHENSIVE COMPARISON — 80 EPOCHS + LR SCHEDULER
# ...
# Augmentation : none
# Max Epochs   : 80
# Patience     : 20
# LR Scheduler : ReduceLROnPlateau (factor=0.5, patience=8)
# ...
#
# ...
#   APPLIANCE: DISH WASHER
# ...
#
#   >> Standard LNN
#       Early stop at epoch 23
#      F1=0.1031  MAE=40.69  SAE=39.5222  (epochs=23, params=66,561)
#
#   >> Advanced LNN
#       Early stop at epoch 20
#      F1=0.0000  MAE=nan  SAE=nan  (epochs=20, params=461,825)
#
#   >> Attention LNN
#       Early stop at epoch 22
#      F1=0.4537  MAE=52.48  SAE=50.6576  (epochs=22, params=396,033)
#
#   >> CNN + LNN
#       Early stop at epoch 38
#      F1=0.3605  MAE=33.38  SAE=33.0975  (epochs=38, params=404,097)
#
#   >> Transformer + LNN
#       Early stop at epoch 21
#      F1=0.4571  MAE=38.14  SAE=38.0165  (epochs=21, params=922,113)
#
#   >> Bidir + LNN
#       Early stop at epoch 22
#      F1=0.1110  MAE=46.44  SAE=45.9303  (epochs=22, params=264,193)
#
# ...
#   APPLIANCE: FRIDGE
# ...
#
# ...
